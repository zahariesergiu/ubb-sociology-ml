# %% [markdown]
# # **Final Project Task 2 -Census Data EDA**

# %% [markdown]
# Requirements
#
# Analyze hours-per-week Target Distribution
#
# Provide visualizations like histograms or density plots for hours-per-week to assess its distribution, outliers, and skewness.
#
# Provide a summary of the dataset using descriptive statistics, such as mean, median, and standard deviation.
#
# Check for missing values and report the number and percentage of missing data for each column.
#
# Plot histograms for at least three numerical columns and discuss their distributions, such as skewness and modality.
#
# Generate bar plots for at least three categorical columns and discuss the frequency distributions.
#
# Identify outliers in at least one numerical column using boxplots.
#
# Create a correlation matrix for target hours-per-week and the rest of numerical variables and discuss the strongest and weakest correlations with the target.
#
# Explore relationships between at least one numerical variable and hours-per-week target using scatter plots and identify any visible trends. Choose the variable that is/are most correlated with hours-per-week.
#
# Analyze the relationship between hours-per-week and all categorical variable using boxplots or violin plots.
#
# Write a summary report of your findings from the EDA, highlighting key patterns or trends, unexpected insights or anomalies, and areas requiring further investigation.
#
# At the end, do the same analysis for the preprocessed dataset (just change the input data in the EDA), and write a report. - Optional
#
# Others? - Optional
#
#
# Deliverable:
#
# - Notebook code with no errors.
# - Include all visuals from the requirements in the notebook: graphs, plots, histograms, heatmap etc
# - Be sure to discuss the findings and add a summary report

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data from the preprocessed csv file - data_normalized.csv
data = pd.read_csv("data/data_normalized.csv")
data.sample(10)
# Out:
#        age    fnlwgt     education  education-num  sex  capital-gain  \
# 4228    38 -0.885361     Assoc-voc       0.357340    0     -0.209221
# 22352   26  1.780943       HS-grad      -0.420060    1     -0.209221
# 30583   20 -0.233839       HS-grad      -0.420060    1     -0.209221
# 22835   61 -1.549284       HS-grad      -0.420060    0     -0.209221
# 25860   27  2.879350     Bachelors       1.134739    0     -0.209221
# 31718   34 -0.336825  Some-college      -0.031360    1     -0.209221
# 16258   36 -0.257014       HS-grad      -0.420060    1     -0.209221
# 11538   47 -0.361866   Prof-school       1.912138    1      1.840901
# 6143    28  0.013251       Masters       1.523438    0     -0.209221
# 11867   26 -0.833422       HS-grad      -0.420060    1      1.316370
#
#        capital-loss  hours-per-week  income  workclass_Local-gov  ...  \
# 4228      -0.217235       -0.029692       0                False  ...
# 22352     -0.217235       -0.029692       0                False  ...
# 30583     -0.217235       -0.029692       0                False  ...
# 22835     -0.217235       -0.029692       0                False  ...
# 25860     -0.217235       -0.029692       0                False  ...
# 31718     -0.217235        2.878609       0                False  ...
# 16258     -0.217235       -0.029692       0                False  ...
# 11538     -0.217235        1.632195       1                False  ...
# 6143      -0.217235       -1.691579       1                 True  ...
# 11867     -0.217235       -0.029692       0                False  ...
#
#        native-country_Puerto-Rico  native-country_Scotland  \
# 4228                        False                    False
# 22352                       False                    False
# 30583                       False                    False
# 22835                       False                    False
# 25860                       False                    False
# 31718                       False                    False
# 16258                       False                    False
# 11538                       False                    False
# 6143                        False                    False
# 11867                       False                    False
#
#        native-country_South  native-country_Taiwan  native-country_Thailand  \
# 4228                  False                  False                    False
# 22352                 False                  False                    False
# 30583                 False                  False                    False
# 22835                 False                  False                    False
# 25860                 False                  False                    False
# 31718                 False                  False                    False
# 16258                 False                  False                    False
# 11538                 False                  False                    False
# 6143                  False                  False                    False
# 11867                 False                  False                    False
#
#        native-country_Trinadad&Tobago  native-country_United-States  \
# 4228                            False                          True
# 22352                           False                          True
# 30583                           False                          True
# 22835                           False                          True
# 25860                           False                         False
# 31718                           False                          True
# 16258                           False                         False
# 11538                           False                          True
# 6143                            False                          True
# 11867                           False                          True
#
#        native-country_Vietnam  native-country_Yugoslavia  age_bin
# 4228                    False                      False    35-44
# 22352                   False                      False    25-34
# 30583                   False                      False    18-24
# 22835                   False                      False    55-64
# 25860                   False                      False    25-34
# 31718                   False                      False    25-34
# 16258                   False                      False    35-44
# 11538                   False                      False    45-54
# 6143                    False                      False    25-34
# 11867                   False                      False    25-34
#
# [10 rows x 86 columns]

# %%
data.columns
# Out:
# Index(['age', 'fnlwgt', 'education', 'education-num', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'income', 'workclass_Local-gov',
#        'workclass_Never-worked', 'workclass_Private', 'workclass_Self-emp-inc',
#        'workclass_Self-emp-not-inc', 'workclass_State-gov',
#        'workclass_Without-pay', 'marital-status_Married-AF-spouse',
#        'marital-status_Married-civ-spouse',
#        'marital-status_Married-spouse-absent', 'marital-status_Never-married',
#        'marital-status_Separated', 'marital-status_Widowed',
#        'occupation_Armed-Forces', 'occupation_Craft-repair',
#        'occupation_Exec-managerial', 'occupation_Farming-fishing',
#        'occupation_Handlers-cleaners', 'occupation_Machine-op-inspct',
#        'occupation_No-occupation', 'occupation_Other-service',
#        'occupation_Priv-house-serv', 'occupation_Prof-specialty',
#        'occupation_Protective-serv', 'occupation_Sales',
#        'occupation_Tech-support', 'occupation_Transport-moving',
#        'relationship_Not-in-family', 'relationship_Other-relative',
#        'relationship_Own-child', 'relationship_Unmarried', 'relationship_Wife',
#        'race_Asian-Pac-Islander', 'race_Black', 'race_Other', 'race_White',
#        'native-country_Canada', 'native-country_China',
#        'native-country_Columbia', 'native-country_Cuba',
#        'native-country_Dominican-Republic', 'native-country_Ecuador',
#        'native-country_El-Salvador', 'native-country_England',
#        'native-country_France', 'native-country_Germany',
#        'native-country_Greece', 'native-country_Guatemala',
#        'native-country_Haiti', 'native-country_Holand-Netherlands',
#        'native-country_Honduras', 'native-country_Hong',
#        'native-country_Hungary', 'native-country_India', 'native-country_Iran',
#        'native-country_Ireland', 'native-country_Italy',
#        'native-country_Jamaica', 'native-country_Japan', 'native-country_Laos',
#        'native-country_Mexico', 'native-country_Nicaragua',
#        'native-country_Outlying-US(Guam-USVI-etc)', 'native-country_Peru',
#        'native-country_Philippines', 'native-country_Poland',
#        'native-country_Portugal', 'native-country_Puerto-Rico',
#        'native-country_Scotland', 'native-country_South',
#        'native-country_Taiwan', 'native-country_Thailand',
#        'native-country_Trinadad&Tobago', 'native-country_United-States',
#        'native-country_Vietnam', 'native-country_Yugoslavia', 'age_bin'],
#       dtype='object')

# %% [markdown]
# #### Analyze hours-per-week Target Distribution
#
# **Provide visualizations like histograms or density plots for hours-per-week to assess its distribution, outliers, and skewness.**

# %%
# Calculate summary statistics
summary_stats = data['hours-per-week'].describe()

# Print summary statistics
print("Summary Statistics for hours-per-Week:")
print(summary_stats)

# Create visualizations for distribution analysis
plt.figure(figsize=(18, 6))

# Histogram with KDE (Density Plot)
plt.subplot(1, 2, 1)
sns.histplot(data['hours-per-week'], kde=True, bins=15, color='blue', edgecolor='black')
plt.title('Hours per Week Distribution (Histogram + KDE)')
plt.xlabel('Hours per Week')
plt.ylabel('Frequency')

# Boxplot for Outlier Detection
plt.subplot(1, 2, 2)
sns.boxplot(x=data['hours-per-week'], color='orange')
plt.title('Hours-per-Week Distribution (Boxplot)')
plt.xlabel('Hours per Week')

# Adjust the layout to avoid overlaps
plt.tight_layout(pad=3.0)

# Save the plot to a PNG file
plt.savefig('graphs/preprocessed/hours-per-week-histogram-and-density-plot.png', dpi=75)

plt.show()
# Out:
# Summary Statistics for hours-per-Week:
# count    3.256100e+04
# mean     8.292320e-18
# std      1.000015e+00
# min     -3.270371e+00
# 25%     -2.969204e-02
# 50%     -2.969204e-02
# 75%      3.857796e-01
# max      3.294081e+00
# Name: hours-per-week, dtype: float64

# %% [markdown]
# ##### Provide a summary of the dataset using descriptive statistics, such as mean, median, and standard deviation.

# %%
# Shows counts, mean, standard deviation, minimum, quartiles, and maximum for numerical columns
data.describe()
# Out:
#                 age        fnlwgt  education-num           sex  capital-gain  \
# count  32561.000000  3.256100e+04   3.256100e+04  32561.000000  3.256100e+04
# mean      38.581647 -9.732565e-17   1.538444e-16      0.669205  4.582598e-17
# std       13.640433  1.000015e+00   1.000015e+00      0.470506  1.000015e+00
# min       17.000000 -1.681631e+00  -3.529656e+00      0.000000 -2.092214e-01
# 25%       28.000000 -6.816910e-01  -4.200596e-01      0.000000 -2.092214e-01
# 50%       37.000000 -1.082193e-01  -3.136003e-02      1.000000 -2.092214e-01
# 75%       48.000000  4.478765e-01   7.460392e-01      1.000000 -2.092214e-01
# max       90.000000  1.226856e+01   2.300838e+00      1.000000  1.045739e+01
#
#        capital-loss  hours-per-week        income
# count  3.256100e+04    3.256100e+04  32561.000000
# mean   8.772402e-17    8.292320e-18      0.240810
# std    1.000015e+00    1.000015e+00      0.427581
# min   -2.172350e-01   -3.270371e+00      0.000000
# 25%   -2.172350e-01   -2.969204e-02      0.000000
# 50%   -2.172350e-01   -2.969204e-02      0.000000
# 75%   -2.172350e-01    3.857796e-01      0.000000
# max    7.270689e+00    3.294081e+00      1.000000

# %% [markdown]
# ##### Check for missing values and report the number and percentage of missing data for each column.

# %%
# Count missing values in each column
missing_values_count = data.isnull().sum()
print(missing_values_count)
# Out:
# age                                 0
# fnlwgt                              0
# education                           0
# education-num                       0
# sex                                 0
#                                  ...
# native-country_Trinadad&Tobago      0
# native-country_United-States        0
# native-country_Vietnam              0
# native-country_Yugoslavia           0
# age_bin                           945
# Length: 86, dtype: int64

# %%
# Apparently there are no missing values in data frame. 
# Use the sample function to explore data
data.sample(n=10)
# Out:
#        age    fnlwgt     education  education-num  sex  capital-gain  \
# 9555    21  2.079157  Some-college      -0.031360    1     -0.209221
# 27092   37 -0.488746       HS-grad      -0.420060    1     -0.209221
# 2428    41 -0.337138       HS-grad      -0.420060    0     -0.209221
# 28799   41 -0.203266  Some-college      -0.031360    0     -0.209221
# 6565    26 -1.269895       HS-grad      -0.420060    0     -0.209221
# 32484   48  0.741884  Some-college      -0.031360    0     -0.209221
# 2121    20 -0.766392       HS-grad      -0.420060    0     -0.209221
# 9987    67  0.802217       7th-8th      -2.363558    1     -0.209221
# 17703   23 -1.487909     Bachelors       1.134739    1     -0.209221
# 5261    27  1.773193       HS-grad      -0.420060    1     -0.209221
#
#        capital-loss  hours-per-week  income  workclass_Local-gov  ...  \
# 9555      -0.217235       -0.860635       0                False  ...
# 27092     -0.217235        0.385780       0                False  ...
# 2428      -0.217235       -0.029692       0                False  ...
# 28799     -0.217235       -0.029692       1                False  ...
# 6565      -0.217235       -0.860635       0                False  ...
# 32484     -0.217235       -0.029692       0                False  ...
# 2121      -0.217235       -0.029692       0                False  ...
# 9987      -0.217235       -0.029692       0                False  ...
# 17703     -0.217235       -2.107050       0                False  ...
# 5261      -0.217235       -0.029692       0                False  ...
#
#        native-country_Puerto-Rico  native-country_Scotland  \
# 9555                        False                    False
# 27092                       False                    False
# 2428                        False                    False
# 28799                       False                    False
# 6565                        False                    False
# 32484                       False                    False
# 2121                        False                    False
# 9987                        False                    False
# 17703                       False                    False
# 5261                        False                    False
#
#        native-country_South  native-country_Taiwan  native-country_Thailand  \
# 9555                  False                  False                    False
# 27092                 False                  False                    False
# 2428                  False                  False                    False
# 28799                 False                  False                    False
# 6565                  False                  False                    False
# 32484                 False                  False                    False
# 2121                  False                  False                    False
# 9987                  False                  False                    False
# 17703                 False                  False                    False
# 5261                  False                  False                    False
#
#        native-country_Trinadad&Tobago  native-country_United-States  \
# 9555                            False                          True
# 27092                           False                          True
# 2428                            False                          True
# 28799                           False                          True
# 6565                            False                          True
# 32484                           False                          True
# 2121                            False                          True
# 9987                            False                          True
# 17703                           False                          True
# 5261                            False                          True
#
#        native-country_Vietnam  native-country_Yugoslavia  age_bin
# 9555                    False                      False    18-24
# 27092                   False                      False    35-44
# 2428                    False                      False    35-44
# 28799                   False                      False    35-44
# 6565                    False                      False    25-34
# 32484                   False                      False    45-54
# 2121                    False                      False    18-24
# 9987                    False                      False      65+
# 17703                   False                      False    18-24
# 5261                    False                      False    25-34
#
# [10 rows x 86 columns]

# %%
# There are no missing missing values in the data set

# %% [markdown]
# ##### Plot histograms for at least three numerical columns and discuss their distributions, such as skewness and modality.

# %%
# Check the type of columns in dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 86 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        32561 non-null  int64
#  1   fnlwgt                                     32561 non-null  float64
#  2   education                                  32561 non-null  object
#  3   education-num                              32561 non-null  float64
#  4   sex                                        32561 non-null  int64
#  5   capital-gain                               32561 non-null  float64
#  6   capital-loss                               32561 non-null  float64
#  7   hours-per-week                             32561 non-null  float64
#  8   income                                     32561 non-null  int64
#  9   workclass_Local-gov                        32561 non-null  bool
#  10  workclass_Never-worked                     32561 non-null  bool
#  11  workclass_Private                          32561 non-null  bool
#  12  workclass_Self-emp-inc                     32561 non-null  bool
#  13  workclass_Self-emp-not-inc                 32561 non-null  bool
#  14  workclass_State-gov                        32561 non-null  bool
#  15  workclass_Without-pay                      32561 non-null  bool
#  16  marital-status_Married-AF-spouse           32561 non-null  bool
#  17  marital-status_Married-civ-spouse          32561 non-null  bool
#  18  marital-status_Married-spouse-absent       32561 non-null  bool
#  19  marital-status_Never-married               32561 non-null  bool
#  20  marital-status_Separated                   32561 non-null  bool
#  21  marital-status_Widowed                     32561 non-null  bool
#  22  occupation_Armed-Forces                    32561 non-null  bool
#  23  occupation_Craft-repair                    32561 non-null  bool
#  24  occupation_Exec-managerial                 32561 non-null  bool
#  25  occupation_Farming-fishing                 32561 non-null  bool
#  26  occupation_Handlers-cleaners               32561 non-null  bool
#  27  occupation_Machine-op-inspct               32561 non-null  bool
#  28  occupation_No-occupation                   32561 non-null  bool
#  29  occupation_Other-service                   32561 non-null  bool
#  30  occupation_Priv-house-serv                 32561 non-null  bool
#  31  occupation_Prof-specialty                  32561 non-null  bool
#  32  occupation_Protective-serv                 32561 non-null  bool
#  33  occupation_Sales                           32561 non-null  bool
#  34  occupation_Tech-support                    32561 non-null  bool
#  35  occupation_Transport-moving                32561 non-null  bool
#  36  relationship_Not-in-family                 32561 non-null  bool
#  37  relationship_Other-relative                32561 non-null  bool
#  38  relationship_Own-child                     32561 non-null  bool
#  39  relationship_Unmarried                     32561 non-null  bool
#  40  relationship_Wife                          32561 non-null  bool
#  41  race_Asian-Pac-Islander                    32561 non-null  bool
#  42  race_Black                                 32561 non-null  bool
#  43  race_Other                                 32561 non-null  bool
#  44  race_White                                 32561 non-null  bool
#  45  native-country_Canada                      32561 non-null  bool
#  46  native-country_China                       32561 non-null  bool
#  47  native-country_Columbia                    32561 non-null  bool
#  48  native-country_Cuba                        32561 non-null  bool
#  49  native-country_Dominican-Republic          32561 non-null  bool
#  50  native-country_Ecuador                     32561 non-null  bool
#  51  native-country_El-Salvador                 32561 non-null  bool
#  52  native-country_England                     32561 non-null  bool
#  53  native-country_France                      32561 non-null  bool
#  54  native-country_Germany                     32561 non-null  bool
#  55  native-country_Greece                      32561 non-null  bool
#  56  native-country_Guatemala                   32561 non-null  bool
#  57  native-country_Haiti                       32561 non-null  bool
#  58  native-country_Holand-Netherlands          32561 non-null  bool
#  59  native-country_Honduras                    32561 non-null  bool
#  60  native-country_Hong                        32561 non-null  bool
#  61  native-country_Hungary                     32561 non-null  bool
#  62  native-country_India                       32561 non-null  bool
#  63  native-country_Iran                        32561 non-null  bool
#  64  native-country_Ireland                     32561 non-null  bool
#  65  native-country_Italy                       32561 non-null  bool
#  66  native-country_Jamaica                     32561 non-null  bool
#  67  native-country_Japan                       32561 non-null  bool
#  68  native-country_Laos                        32561 non-null  bool
#  69  native-country_Mexico                      32561 non-null  bool
#  70  native-country_Nicaragua                   32561 non-null  bool
#  71  native-country_Outlying-US(Guam-USVI-etc)  32561 non-null  bool
#  72  native-country_Peru                        32561 non-null  bool
#  73  native-country_Philippines                 32561 non-null  bool
#  74  native-country_Poland                      32561 non-null  bool
#  75  native-country_Portugal                    32561 non-null  bool
#  76  native-country_Puerto-Rico                 32561 non-null  bool
#  77  native-country_Scotland                    32561 non-null  bool
#  78  native-country_South                       32561 non-null  bool
#  79  native-country_Taiwan                      32561 non-null  bool
#  80  native-country_Thailand                    32561 non-null  bool
#  81  native-country_Trinadad&Tobago             32561 non-null  bool
#  82  native-country_United-States               32561 non-null  bool
#  83  native-country_Vietnam                     32561 non-null  bool
#  84  native-country_Yugoslavia                  32561 non-null  bool
#  85  age_bin                                    31616 non-null  object
# dtypes: bool(76), float64(5), int64(3), object(2)
# memory usage: 4.8+ MB

# %%
# We select 'age', 'income' and 'hours-per-week' columns, as they are all numerical
numerical_cols = ['age', 'hours-per-week', 'capital-gain'] 

# Create subplots for each column
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

# Plot histograms for each column
for i, col in enumerate(numerical_cols):
    sns.histplot(data=data, x=col, kde=True, ax=axes[i])
    axes[i].set_title(f'Histogram of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')

# Adjust the layout to avoid overlaps
plt.tight_layout(pad=3.0)

# Save the plot to a PNG file
plt.savefig('graphs/preprocessed/histograms-for-age-hours-per-week-capital-gain.png', dpi=75)

plt.show()

# %% [markdown]
# #### Histogram discussion
# ##### Age:
#
# Right-skewed: Most individuals are younger, with a tail towards older ages.
# Peak around 35-40: The highest frequency of individuals is in the 35-40 age range.
#
# ##### Hours per week:
#
# Unimodal - A single peak indicates a common working pattern.
# Peak around 40: Most people work a standard 40-hour week.
# Slight right skew: Some individuals work significantly more hours.
#
# ##### Capital gain:
#
# Highly right-skewed: Most individuals have low or no capital gains, with a few having very high gains.
# Bimodal: There might be a second peak at zero, indicating many individuals with no capital gain.

# %% [markdown]
# -------------------------------

# %% [markdown]
# #### Generate bar plots for at least three categorical columns and discuss the frequency distributions.

# %%
# Categorical columns: 'education', 'workclass_Private', 'marital-status_Married-AF-spouse'
categorical_cols = ['education', 'workclass_Private', 'marital-status_Married-AF-spouse']

# Create subplots for each column
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

# Plot bar plots for each categorical column
for i, col in enumerate(categorical_cols):
    sns.countplot(x=col, data=data, ax=axes[i])
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')
    axes[i].tick_params(axis='x', rotation=45, labelsize=8)  # Rotate x-axis labels for better readability

# Adjust the layout to avoid overlaps
plt.tight_layout(pad=3.0)

# Save the plot to a PNG file
plt.savefig('graphs/preprocessed/barplot-for-education-marital-status-race.png', dpi=75)

plt.show()

# %% [markdown]
# ### **1. Distribution of Education**
# - **Key Insights**:
#   - The majority of individuals have a **High School Graduate (HS-grad)** level of education, with over 10,000 individuals in this category.
#   - **Some College** follows as the second most common education level, with around 7,000 individuals.
#   - Advanced degrees, such as **Doctorate** and **Masters**, are less common, representing a smaller portion of the population.
#   - Lower education levels, such as **Preschool**, **1st-4th**, and **5th-6th**, are rare.
#
# ---
#
# ### **2. Distribution of Workclass (Private)**
# - **Key Insights**:
#   - A significant majority of individuals (~25,000) work in the **Private sector**, as indicated by the `True` count.
#   - A smaller subset (~10,000) is categorized as not working in the private sector (`False`).
#   - This highlights the dominance of private employment in the dataset.
#
# ---
#
# ### **3. Distribution of Marital Status (Married-AF-spouse)**
# - **Key Insights**:
#   - The majority of the population (~30,000) is **not married to Armed Forces (Marrie

# %% [markdown]
# ----------------------------------------------------------------------

# %% [markdown]
# #### Identify outliers in at least one numerical column using boxplots.

# %%
# Calculate the first and third quartiles
Q1 = data['age'].quantile(0.25)
Q3 = data['age'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

# Identify outliers
outliers = data[(data['age'] < lower_bound) | (data['age'] > upper_bound)]

# Print the outliers
print(f"Outliers in 'age':\n{outliers['age']}") 

# Create a boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x='age', data=data)

# Plot the outliers as red dots
sns.scatterplot(x=outliers['age'], y=[0]*len(outliers), color='red', label='Outliers')

plt.title('Boxplot for Age with Outliers')
plt.xlabel('Age')
plt.legend()

# Adjust the layout to avoid overlaps
plt.tight_layout(pad=3.0)

# Save the plot to a PNG file
plt.savefig('graphs/preprocessed//boxplot-for-age.png', dpi=75)

plt.show()
# Out:
# Outliers in 'age':
# 74       79
# 222      90
# 430      80
# 918      81
# 1040     90
#          ..
# 32277    90
# 32367    90
# 32459    85
# 32494    82
# 32525    81
# Name: age, Length: 143, dtype: int64

# %% [markdown]
# 1. **Central Tendency**:
#    - The median age is approximately **40 years**, indicating that half of the individuals are younger than 40, and half are older.
#
# 2. **Spread**:
#    - The interquartile range (IQR) spans from around **30 to 50 years**, representing the middle 50% of the data.
#    - Most individuals are within this range, indicating that the age distribution is relatively concentrated around the working-age population.
#
# 3. **Outliers**:
#    - Outliers are observed beyond the upper whisker (approximately **80 years**).
#    - These outliers may represent older individuals who are still part of the working or economically active population.
#    - These values warrant further investigation to confirm if they are legitimate entries or errors.
#
# 4. **Skewness**:
#    - The boxplot is slightly skewed to the right, as indicated by the presence of outliers on the upper end of the age distribution.
#
# ---
#
# ## **Overall Observations**
# - The age distribution highlights a workforce concentrated in the **30–50 year** range.
# - The outliers (ages beyond 80) suggest that a small subset of individuals are working at an older age.

# %% [markdown]
# -----------------------------

# %% [markdown]
# #### Create a correlation matrix for target hours-per-week and the rest of numerical variables and discuss the strongest and weakest correlations with the target.

# %%
# Select the numerical columns 
numerical_cols = ['age', 'education-num', 'hours-per-week', 'capital-gain', 'capital-loss'] 

# Calculate the correlation matrix
correlation_matrix = data[numerical_cols].corr()

# Create a heatmap to visualize the correlations
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix for Numerical Variables')

# Adjust the layout to avoid overlaps
plt.tight_layout(pad=3.0)

# Save the plot to a PNG file
plt.savefig('graphs/preprocessed/corr-matrix-for-hours-per-week.png', dpi=75)

plt.show()

# %%
# Correlations with 'hours-per-week'
correlation_target = data[numerical_cols].corr()['hours-per-week'].drop('hours-per-week')

# Bar plot for correlations with target variable
plt.figure(figsize=(6, 5))
correlation_target.plot(kind='bar', color='darkgrey')

plt.title('Correlation with Hours-per-week')
plt.ylabel('Correlation Coefficient')
plt.xlabel('Variables')

# Adjust the layout to avoid overlaps
plt.tight_layout(pad=3.0)

# Save the plot to a PNG file
plt.savefig('graphs/preprocessed//bars-for-correlations-with-hours-per-week.png', dpi=75)

plt.show()

# %% [markdown]
# The strongest correlation with the target variable (hours-per-week) is education-num. This indicates that the level of education (represented as education-num) has the most significant positive relationship with the number of hours worked per week.
#
# The weakest correlation is with capital-loss. This suggests that the amount of capital-loss has very little relationship with the number of hours worked per week.

# %% [markdown]
# ---------------------------------------

# %% [markdown]
# ##### Explore relationships between at least one numerical variable and hours-per-week target using scatter plots and identify any visible trends. Choose the variable that is/are most correlated with hours-per-week.

# %%
# List of numerical columns excluding 'hours-per-week' as target
numerical_cols_new = ['age', 'education-num', 'capital-gain', 'capital-loss']

# Define the number of subplots
num_cols = len(numerical_cols_new)
fig, axes = plt.subplots(nrows=1, ncols=num_cols, figsize=(5 * num_cols, 5))

# Loop through each numerical column and create a scatter plot in a subplot
for i, col in enumerate(numerical_cols_new):
    ax = axes[i]  # Correctly reference each subplot
    ax.scatter(data[col], data['hours-per-week'], alpha=0.2, color='red', marker='x')
    ax.grid(axis='y', linestyle='--', alpha=0.6)
    ax.set_title(f'{col} vs. Hours per Week')
    ax.set_xlabel(col)
    ax.set_ylabel('Hours per Week')

# Adjust the layout to avoid overlaps
plt.tight_layout(pad=3.0)

# Save the plot to a PNG file
plt.savefig('graphs/preprocessed//scatterplots-hours-per-week.png', dpi=75)

plt.show()

# %% [markdown]
# Among all variables, education-num appears to have the strongest correlation with hours-per-week. Higher education levels are associated with more hours worked, but the correlation is a weak one.

# %% [markdown]
# ##### Alternate visualisation for correlations of hours-per-week with the other numerical variables

# %%
# Create hexbin plots for each numerical variable against 'hours-per-week'
fig, axes = plt.subplots(nrows=1, ncols=num_cols, figsize=(5 * num_cols, 5))

for i, col in enumerate(numerical_cols_new):
    ax = axes[i]
    hb = ax.hexbin(data[col], data['hours-per-week'], gridsize=30, cmap='Oranges', mincnt=1)
    ax.set_title(f'{col} vs. Hours per Week')
    ax.set_xlabel(col)
    ax.set_ylabel('Hours per Week')
    fig.colorbar(hb, ax=ax)

# Adjust the layout to avoid overlaps
plt.tight_layout(pad=3.0)

# Save the plot to a PNG file
plt.savefig('graphs/preprocessed/hexbinfor-hours-per-week.png', dpi=75)

plt.show()

# %% [markdown]
# **Age vs. Hours per Week:**
#
# Most people aged 30–50 work around 40 hours per week.
# Younger (<30) and older (>60) individuals tend to work fewer hours.
#
# **Education-num vs. Hours per Week:**
#
# People with an average education level (~10 years) mostly work 40 hours per week.
# Education level has little impact on hours worked.
#
# **Capital-gain vs. Hours per Week:**
#
# Most people have no capital gains and work ~40 hours per week.
# Higher capital gains (>20,000) are rare and show no clear link to hours worked.
#
# **Capital-loss vs. Hours per Week:**
#
# Most people have no capital losses and work ~40 hours per week.
# Higher capital losses (>1,000) are uncommon and show no strong relationship with hours worked.

# %% [markdown]
# ------------------------

# %% [markdown]
# #### Analyze the relationship between hours-per-week and all categorical variable using boxplots or violin plots.

# %%
import math
# Categorical columns: 'education', 'sex','workclass_Private', 'marital-status_Married-AF-spouse','native-country_United-States'
categorical_cols = ['education', 'sex','workclass_Private', 'marital-status_Married-AF-spouse','native-country_United-States']

# Define the number of rows and columns
num_cols = 2  # Number of plots per row
num_rows = math.ceil(len(categorical_cols) / num_cols)  # Calculate required rows

# Create subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(10 * num_cols, 6 * num_rows))
axes = axes.flatten()  # Flatten axes for easy indexing

# Loop through categorical columns and create violin plots
for i, var in enumerate(categorical_cols):
    sns.violinplot(
        data=data,
        x=var,
        y="hours-per-week",
        ax=axes[i],
        hue=var,
        palette="muted",
        legend=False  # Disable the legend as it's redundant
    )
    axes[i].set_title(f'{var} vs Hours per Week')
    axes[i].set_xlabel(var)
    axes[i].set_ylabel("Hours per Week")
    axes[i].tick_params(axis='x', rotation=45)  # Rotate x-axis labels for readability
    axes[i].grid(axis='y', linestyle='--', color='lightgray')  # Add dotted grid on y-axis

# Remove any unused subplots
for j in range(len(categorical_cols), len(axes)):
    fig.delaxes(axes[j])


# Adjust the layout to avoid overlaps
plt.tight_layout(pad=3.0)

# Save the plot to a PNG file
plt.savefig('graphs/preprocessed/hours-per-week-vs-categorical-vars-violin-plot.png', dpi=75)

plt.show()

# %% [markdown]
# ### **1. Education vs. Hours per Week**
# - **Key Insights**:
#   - Individuals with higher education levels (e.g., **Doctorate**, **Masters**) tend to work more consistent hours, centered around 40–50 hours per week.
#   - Individuals with lower education levels (e.g., **Preschool**, **1st-4th**) show more variability and tend to work fewer hours on average.
#   - **HS-grad** and **Some-college** represent the most frequent categories, with distributions centered near 40 hours per week.
#
# ---
#
# ### **2. Sex vs. Hours per Week**
# - **Key Insights**:
#   - Males (category **1**) tend to work slightly longer hours than females (category **0**), with a broader spread in hours worked.
#   - Females display a more concentrated distribution around 40 hours per week.
#
# ---
#
# ### **3. Workclass (Private) vs. Hours per Week**
# - **Key Insights**:
#   - Individuals working in the private sector (**True**) have a wider range of working hours compared to those not in the private sector (**False**).
#   - Private sector workers have a peak distribution near 40–50 hours per week, while others have a more dispersed distribution.
#
# ---
#
# ### **4. Marital Status (Married-AF-spouse) vs. Hours per Week**
# - **Key Insights**:
#   - Individuals married to Armed Forces (**True**) have a tightly concentrated distribution of working hours around 40 hours per week.
#   - Those not married to Armed Forces (**False**) show greater variability in hours worked, with more frequent outliers.
#
# ---
#
# ### **5. Native Country (United States) vs. Hours per Week**
# - **Key Insights**:
#   - Individuals from the United States (**True**) tend to work more consistent hours, with a peak around 40 hours per week.
#   - Those from other countries (**False**) show a slightly broader distribution with some working fewer hours.
#
# ---
#
# ### **Overall Observations**
# - **Consistent Patterns**:
#   - Across most categories, the typical working hours are concentrated around **40–50 hours per week**.
#   - Variability in working hours is more prominent in certain groups, such as males and individuals with lower education levels.
# - **Areas of Investigation**:
#   - The outliers observed in multiple categories, such as hours significantly lower or higher than the median, may require further exploration.

# %% [markdown]
# --------------------------------------------

# %% [markdown]
# #### Use a heatmap to visualize correlations among variables and highlight the top three strongest correlations.

# %%
# Select numerical columns
numerical_cols = ['age', 'education-num', 'hours-per-week', 'capital-gain', 'capital-loss']
corr_matrix = data[numerical_cols].corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix for Numerical Variables')

# Strongest correlations between variables
corr_pairs = corr_matrix.unstack()
sorted_pairs = corr_pairs.sort_values(ascending=False)

# Display top 3 correlations (excluding auto-correlations)
print("Top 3 positive correlations:")
top_3_df = sorted_pairs[-3:].reset_index().rename(columns={0: 'Correlation'})
print(top_3_df)

# Adjust the layout to avoid overlaps
plt.tight_layout(pad=3.0)

# Save the plot to a PNG file
plt.savefig('graphs/preprocessed/heatmap-correlation-numerical-values.png', dpi=75)

plt.show()
# Out:
# Top 3 positive correlations:
#         level_0        level_1  Correlation
# 0           age  education-num     0.036527
# 1  capital-gain   capital-loss    -0.045450
# 2  capital-loss   capital-gain    -0.045450

# %% [markdown]
# # ***Summary Report from the EDA***
#
# ## **Key Patterns and Trends**
# 1. **Hours-per-Week Distribution**:
#    - Most individuals work around **40 hours per week**, indicating a concentration around the standard workweek.
#    - A few observations highlight individuals working significantly fewer or greater hours, with potential outliers near the extremes (e.g., <20 hours or >80 hours).
#
# 2. **Demographic Insights**:
#    - **Education**:
#      - Higher education levels (e.g., **Doctorate**, **Masters**) are associated with more consistent working hours and higher income levels.
#      - Lower education levels (e.g., **Preschool**, **1st-4th grade**) show more variability in working hours.
#    - **Sex**:
#      - Males generally work longer hours compared to females, with a broader distribution in the number of hours worked.
#
# 3. **Workclass and Marital Status**:
#    - **Private sector** employment dominates the dataset, with most individuals working in this category.
#    - Married individuals (e.g., **Married-civ-spouse**) show more consistent hours compared to other groups (e.g., **Never-married** or **Divorced**).
#
# 4. **Income and Hours-per-Week**:
#    - A positive correlation exists between higher income levels (>50K) and hours worked per week.
#    - Lower income groups (<=50K) exhibit more variability in working hours, including part-time work.
#
# 5. **Correlation Analysis**:
#    - **Education-num** has the strongest positive correlation with hours-per-week, reflecting the influence of education on work consistency and effort.
#    - **Capital-gain** and **capital-loss** show weaker or no meaningful correlation with hours-per-week.
#
# ---
#
# ## **Unexpected Insights or Anomalies**
# 1. **Outliers in Hours-per-Week**:
#    - A small number of individuals work extremely long or short hours, possibly representing unique cases such as self-employment, part-time work, or data entry errors.
# 2. **Cultural and Regional Factors**:
#    - Differences in working hours are observed across categories like **native-country**, with some non-US countries exhibiting lower or more variable working hours.
#
# ---
#
# ## **Areas Requiring Further Investigation**
# 1. **Outlier Analysis**:
#    - Investigate extreme values in `hours-per-week` to determine if they are valid or require correction.
# 2. **Regional Analysis**:
#    - Explore the relationship between `native-country` and working hours to identify trends influenced by cultural or economic factors.
