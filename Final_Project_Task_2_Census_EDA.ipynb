# %% [markdown]
# # **Final Project Task 2 - Census EDA**

# %% [markdown]
# Requirements
#
# - Analyze hours-per-week Target Distribution **1p**
#     - Provide visualizations like histograms or density plots for hours-per-week to assess its distribution, outliers, and skewness.
#
# - Provide a summary of the dataset using descriptive statistics, such as mean, median, and standard deviation. **1p**
#
# - Check for missing values and report the number and percentage of missing data for each column. **1p**
#
# - Identify outliers in at least one numerical column using boxplots. **1p**
#
# - Write a summary report of your findings from the EDA, highlighting key patterns or trends, unexpected insights or anomalies, and areas requiring further investigation. **1p**
#
#
# - Plot histograms for at least three numerical columns and discuss their distributions, such as skewness and modality. - Optional
#
# - Generate bar plots for at least three categorical columns and discuss the frequency distributions. - Optional
#
# - Create a correlation matrix for target hours-per-week and the rest of numerical variables and discuss the strongest and weakest correlations with the target. - Optional
#
# - Explore relationships between at least one numerical variable and hours-per-week target using scatter plots and identify any visible trends. Choose the variable that is/are most correlated with hours-per-week. - Optional
#
# - Analyze the relationship between hours-per-week and all categorical variable using boxplots or violin plots. - Optional
#
# - At the end, do the same analysis for the preprocessed dataset (just change the input data in the EDA), and write a report. - Optional
#
# - Others? - Optional
#
#
# Deliverable:
#
# - Notebook code with no errors.
# - Include all visuals from the requirements in the notebook: graphs, plots, histograms, heatmap etc
# - Be sure to discuss the findings and add a summary report

# %%
import pandas as pd

# %%
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"
columns = [
    "age", "workclass", "fnlwgt", "education", "education-num", "marital-status",
    "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss",
    "hours-per-week", "native-country", "income"
]

data = pd.read_csv(data_url, header=None, names=columns, na_values=" ?", skipinitialspace=True)
data.sample(10)
# Out:
#        age  workclass  fnlwgt     education  education-num  \
# 14189   45    Private  102597       HS-grad              9
# 13646   62          ?  129246       HS-grad              9
# 13452   21    Private   83033  Some-college             10
# 28857   48    Private  149210       HS-grad              9
# 19367   43  Local-gov  188291   Prof-school             15
# 15940   43  State-gov  222978     Doctorate             16
# 18886   54    Private  138944       HS-grad              9
# 29114   33  Local-gov  190290     Assoc-voc             11
# 19268   18    Private   59202       HS-grad              9
# 10785   45    Private  242994  Some-college             10
#
#            marital-status       occupation    relationship   race     sex  \
# 14189             Widowed     Adm-clerical       Unmarried  White  Female
# 13646  Married-civ-spouse                ?         Husband  White    Male
# 13452       Never-married     Adm-clerical       Own-child  White  Female
# 28857           Separated     Craft-repair       Unmarried  Black    Male
# 19367  Married-civ-spouse   Prof-specialty         Husband  White    Male
# 15940           Separated   Prof-specialty       Unmarried  White  Female
# 18886  Married-civ-spouse            Sales         Husband  White    Male
# 29114       Never-married  Protective-serv   Not-in-family  White    Male
# 19268       Never-married  Priv-house-serv  Other-relative  White  Female
# 10785       Never-married            Sales   Not-in-family  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 14189             0             0              35  United-States  <=50K
# 13646             0             0              40  United-States  <=50K
# 13452          2176             0              20  United-States  <=50K
# 28857             0             0              45  United-States  <=50K
# 19367         15024             0              45  United-States   >50K
# 15940             0             0              40  United-States   >50K
# 18886             0             0              44  United-States  <=50K
# 29114             0             0              56  United-States  <=50K
# 19268             0             0              10  United-States  <=50K
# 10785             0             0              52  United-States  <=50K

# %%
import matplotlib.pyplot as plt
import seaborn as sns

X_train = pd.read_csv("X_train.csv")
y_train = pd.read_csv("y_train.csv")

X_train.head()
# Out:
#         age    fnlwgt  education-num  capital-gain  capital-loss  \
# 0  0.121009 -1.482611             10     -0.145638     -0.216946
# 1  1.321321 -0.072277              9     -0.145638     -0.216946
# 2  0.721165  0.052373              7     -0.145638     -0.216946
# 3  0.871204 -0.019658             13     -0.145638     -0.216946
# 4  0.571126  0.528541             10     -0.145638     -0.216946
#
#    hours-per-week  workclass_Federal-gov  workclass_Local-gov  \
# 0        0.773106                  False                False
# 1       -0.040184                  False                False
# 2       -0.040184                  False                False
# 3        0.773106                  False                False
# 4        0.773106                  False                False
#
#    workclass_Never-worked  workclass_Private  ...  native-country_Portugal  \
# 0                   False               True  ...                    False
# 1                   False               True  ...                    False
# 2                   False               True  ...                    False
# 3                   False               True  ...                    False
# 4                   False              False  ...                    False
#
#    native-country_Puerto-Rico  native-country_Scotland  native-country_South  \
# 0                       False                    False                 False
# 1                       False                    False                 False
# 2                       False                    False                 False
# 3                       False                    False                 False
# 4                       False                    False                 False
#
#    native-country_Taiwan  native-country_Thailand  \
# 0                  False                    False
# 1                  False                    False
# 2                  False                    False
# 3                  False                    False
# 4                  False                    False
#
#    native-country_Trinadad&Tobago  native-country_United-States  \
# 0                           False                          True
# 1                           False                          True
# 2                           False                          True
# 3                           False                          True
# 4                           False                          True
#
#    native-country_Vietnam  native-country_Yugoslavia
# 0                   False                      False
# 1                   False                      False
# 2                   False                      False
# 3                   False                      False
# 4                   False                      False
#
# [5 rows x 100 columns]

# %%
plt.figure(figsize=(8,5))
sns.histplot(X_train["hours-per-week"], bins=30, kde=True)
plt.title("Distribution of Hours per Week")
plt.show()

# %% [markdown]
# Most values of hours-per-week variable are around the 40 hour mark

# %%
X_train.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  25916.000000  25916.000000   25916.000000  25916.000000  25916.000000
# mean      -0.000483      0.000867      10.071539     -0.001505     -0.000871
# std        1.003379      1.001484       2.570776      0.992947      0.998186
# min       -1.604441     -1.681896       1.000000     -0.145638     -0.216946
# 25%       -0.779226     -0.679778       9.000000     -0.145638     -0.216946
# 50%       -0.104050     -0.107289      10.000000     -0.145638     -0.216946
# 75%        0.646145      0.447477      12.000000     -0.145638     -0.216946
# max        2.971751     12.260472      16.000000     13.370344     10.625457
#
#        hours-per-week
# count    25916.000000
# mean        -0.004183
# std          0.999934
# min         -3.212014
# 25%         -0.040184
# 50%         -0.040184
# 75%          0.366461
# max          4.758226

# %% [markdown]
# Summary of descriptive statistics

# %%
missing = X_train.isnull().sum()
missing_percent = (missing / len(X_train)) * 100

pd.DataFrame({
    "Missing Values": missing,
    "Percentage (%)": missing_percent
})
# Out:
#                                 Missing Values  Percentage (%)
# age                                          0             0.0
# fnlwgt                                       0             0.0
# education-num                                0             0.0
# capital-gain                                 0             0.0
# capital-loss                                 0             0.0
# ...                                        ...             ...
# native-country_Thailand                      0             0.0
# native-country_Trinadad&Tobago               0             0.0
# native-country_United-States                 0             0.0
# native-country_Vietnam                       0             0.0
# native-country_Yugoslavia                    0             0.0
#
# [100 rows x 2 columns]

# %% [markdown]
# No missing values - solved in task 1

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=X_train["hours-per-week"])
plt.show()

# %% [markdown]
# Showcases the presence of outliers
