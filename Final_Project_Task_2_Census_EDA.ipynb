# %% [markdown]
# # **Final Project Task 2 - Census EDA**

# %% [markdown]
# Requirements
#
# - Analyze hours-per-week Target Distribution **1p**
#     - Provide visualizations like histograms or density plots for hours-per-week to assess its distribution, outliers, and skewness.
#
# - Provide a summary of the dataset using descriptive statistics, such as mean, median, and standard deviation. **1p**
#
# - Check for missing values and report the number and percentage of missing data for each column. **1p**
#
# - Identify outliers in at least one numerical column using boxplots. **1p**
#
# - Write a summary report of your findings from the EDA, highlighting key patterns or trends, unexpected insights or anomalies, and areas requiring further investigation. **1p**
#
#
# - Plot histograms for at least three numerical columns and discuss their distributions, such as skewness and modality. - Optional
#
# - Generate bar plots for at least three categorical columns and discuss the frequency distributions. - Optional
#
# - Create a correlation matrix for target hours-per-week and the rest of numerical variables and discuss the strongest and weakest correlations with the target. - Optional
#
# - Explore relationships between at least one numerical variable and hours-per-week target using scatter plots and identify any visible trends. Choose the variable that is/are most correlated with hours-per-week. - Optional
#
# - Analyze the relationship between hours-per-week and all categorical variable using boxplots or violin plots. - Optional
#
# - At the end, do the same analysis for the preprocessed dataset (just change the input data in the EDA), and write a report. - Optional
#
# - Others? - Optional
#
#
# Deliverable:
#
# - Notebook code with no errors.
# - Include all visuals from the requirements in the notebook: graphs, plots, histograms, heatmap etc
# - Be sure to discuss the findings and add a summary report

# %%
import pandas as pd

# %%
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"
columns = [
    "age", "workclass", "fnlwgt", "education", "education-num", "marital-status",
    "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss",
    "hours-per-week", "native-country", "income"
]

data = pd.read_csv(data_url, header=None, names=columns, na_values=" ?", skipinitialspace=True)
data.sample(10)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 9873    47         Local-gov  285060       Masters             14
# 28277   20           Private   48121       HS-grad              9
# 9000    58  Self-emp-not-inc  266707       1st-4th              2
# 32347   36         State-gov  212143     Bachelors             13
# 27135   61           Private  270056       HS-grad              9
# 565     20           Private   27337       HS-grad              9
# 23232   20      Never-worked  462294  Some-college             10
# 2378    25           Private  212302  Some-college             10
# 1360    33           Private  105974       HS-grad              9
# 10793   67           Private  279980  Some-college             10
#
#            marital-status         occupation   relationship  \
# 9873   Married-civ-spouse    Exec-managerial        Husband
# 28277       Never-married  Handlers-cleaners      Own-child
# 9000   Married-civ-spouse   Transport-moving        Husband
# 32347  Married-civ-spouse       Adm-clerical           Wife
# 27135            Divorced       Adm-clerical  Not-in-family
# 565         Never-married  Handlers-cleaners      Own-child
# 23232       Never-married                  ?      Own-child
# 2378            Separated       Adm-clerical      Unmarried
# 1360        Never-married       Craft-repair  Not-in-family
# 10793  Married-civ-spouse   Transport-moving        Husband
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 9873                White    Male             0          1977              41
# 28277               White    Male             0             0              40
# 9000                White    Male             0          2179              18
# 32347               White  Female             0             0              20
# 27135  Asian-Pac-Islander  Female             0             0              40
# 565    Amer-Indian-Eskimo    Male             0             0              48
# 23232               Black    Male             0             0              40
# 2378                White  Female             0             0              40
# 1360                White    Male             0             0              41
# 10793               White    Male         10605             0              10
#
#       native-country income
# 9873   United-States   >50K
# 28277  United-States  <=50K
# 9000   United-States  <=50K
# 32347  United-States   >50K
# 27135          Japan  <=50K
# 565    United-States  <=50K
# 23232  United-States  <=50K
# 2378   United-States  <=50K
# 1360   United-States  <=50K
# 10793  United-States   >50K

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train = pd.read_csv("X_train.csv")
X_test = pd.read_csv("X_test.csv")
y_train = pd.read_csv("y_train.csv")
y_test = pd.read_csv("y_test.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(y_train, bins=30, kde=True)
plt.title("Distribution of Hours per Week")
plt.xlabel("Hours per Week")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# hours-per-week distribution

# %%
y_train.describe()
# Out:
#        hours-per-week
# count    25913.000000
# mean        40.448964
# std         12.293542
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
X_train.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  2.591300e+04  2.591300e+04   2.591300e+04  2.591300e+04  2.591300e+04
# mean   1.530054e-16  1.168106e-16  -2.369116e-16  4.771136e-17 -3.235598e-17
# std    1.000019e+00  1.000019e+00   1.000019e+00  1.000019e+00  1.000019e+00
# min   -1.604739e+00 -1.692894e+00  -3.542895e+00 -1.427473e-01 -2.180709e-01
# 25%   -7.787646e-01 -6.855946e-01  -4.230055e-01 -1.427473e-01 -2.180709e-01
# 50%   -1.029675e-01 -1.085730e-01  -3.301932e-02 -1.427473e-01 -2.180709e-01
# 75%    6.479181e-01  4.540064e-01   7.469531e-01 -1.427473e-01 -2.180709e-01
# max    2.975664e+00  1.231565e+01   2.306898e+00  1.384386e+01  1.051875e+01
#
#         workclass_?  workclass_Federal-gov  workclass_Local-gov  \
# count  2.591300e+04           2.591300e+04         2.591300e+04
# mean   9.980996e-17           3.276728e-17        -6.032470e-18
# std    1.000019e+00           1.000019e+00         1.000019e+00
# min   -2.412297e-01          -1.737070e-01        -2.617886e-01
# 25%   -2.412297e-01          -1.737070e-01        -2.617886e-01
# 50%   -2.412297e-01          -1.737070e-01        -2.617886e-01
# 75%   -2.412297e-01          -1.737070e-01        -2.617886e-01
# max    4.145427e+00           5.756820e+00         3.819876e+00
#
#        workclass_Never-worked  workclass_Private  ...  native-country_South  \
# count            2.591300e+04       2.591300e+04  ...          2.591300e+04
# mean             7.156703e-17      -2.604930e-18  ...          8.184965e-17
# std              1.000019e+00       1.000019e+00  ...          1.000019e+00
# min             -1.389211e-02      -1.524709e+00  ...         -4.857556e-02
# 25%             -1.389211e-02      -1.524709e+00  ...         -4.857556e-02
# 50%             -1.389211e-02       6.558629e-01  ...         -4.857556e-02
# 75%             -1.389211e-02       6.558629e-01  ...         -4.857556e-02
# max              7.198333e+01       6.558629e-01  ...          2.058648e+01
#
#        native-country_Taiwan  native-country_Thailand  \
# count           2.591300e+04             2.591300e+04
# mean            7.293805e-17             6.471195e-17
# std             1.000019e+00             1.000019e+00
# min            -4.170852e-02            -2.406648e-02
# 25%            -4.170852e-02            -2.406648e-02
# 50%            -4.170852e-02            -2.406648e-02
# 75%            -4.170852e-02            -2.406648e-02
# max             2.397591e+01             4.155157e+01
#
#        native-country_Trinadad&Tobago  native-country_United-States  \
# count                    2.591300e+04                  2.591300e+04
# mean                     7.732530e-17                 -8.774502e-18
# std                      1.000019e+00                  1.000019e+00
# min                     -2.240381e-02                 -2.910520e+00
# 25%                     -2.240381e-02                  3.435812e-01
# 50%                     -2.240381e-02                  3.435812e-01
# 75%                     -2.240381e-02                  3.435812e-01
# max                      4.463527e+01                  3.435812e-01
#
#        native-country_Vietnam  native-country_Yugoslavia  income_<=50K  \
# count            2.591300e+04               2.591300e+04  2.591300e+04
# mean             9.213227e-17               7.485747e-17  1.864582e-16
# std              1.000019e+00               1.000019e+00  1.000019e+00
# min             -4.611942e-02              -2.324998e-02 -1.779912e+00
# 25%             -4.611942e-02              -2.324998e-02  5.618255e-01
# 50%             -4.611942e-02              -2.324998e-02  5.618255e-01
# 75%             -4.611942e-02              -2.324998e-02  5.618255e-01
# max              2.168284e+01               4.301080e+01  5.618255e-01
#
#         income_>50K   age_squared
# count  2.591300e+04  2.591300e+04
# mean  -8.555140e-17  3.071076e-17
# std    1.000019e+00  1.000019e+00
# min   -5.618255e-01 -1.212068e+00
# 25%   -5.618255e-01 -7.711424e-01
# 50%   -5.618255e-01 -2.500484e-01
# 75%   -5.618255e-01  4.981892e-01
# max    1.779912e+00  3.949880e+00
#
# [8 rows x 110 columns]

# %% [markdown]
# Descriptive statistics

# %%
missing = X_train.isnull().sum()
missing_percent = (missing / len(X_train)) * 100

pd.DataFrame({
    "Missing Values": missing,
    "Percentage (%)": missing_percent
})
# Out:
#                            Missing Values  Percentage (%)
# age                                     0             0.0
# fnlwgt                                  0             0.0
# education-num                           0             0.0
# capital-gain                            0             0.0
# capital-loss                            0             0.0
# ...                                   ...             ...
# native-country_Vietnam                  0             0.0
# native-country_Yugoslavia               0             0.0
# income_<=50K                            0             0.0
# income_>50K                             0             0.0
# age_squared                             0             0.0
#
# [110 rows x 2 columns]

# %% [markdown]
# Missing values

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=y_train.squeeze())
plt.title("Boxplot of Hours per Week")
plt.xlabel("Hours per Week")
plt.show()

# %% [markdown]
# The distribution of hours-per-week is around 40 hours, indicating a typical full-time work environment.
# There are some extreme values, some outliers, for example 80+ hours, or <20 hours
# No missing values
